# %%
import pandas as pd 
import numpy as np 
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv(r"Viz-Quest 2.0 Round 2.csv")
df
# Out:
#        Attack category   Attack subcategory Protocol     Source IP  \
# 0       Reconnaissance                 HTTP      tcp  175.45.176.0
# 1             Exploits     Unix 'r' Service      udp  175.45.176.3
# 2             Exploits              Browser      tcp  175.45.176.2
# 3             Exploits  Miscellaneous Batch      tcp  175.45.176.2
# 4             Exploits            Cisco IOS      tcp  175.45.176.2
# ...                ...                  ...      ...           ...
# 178026         Generic                 IXIA      udp  175.45.176.0
# 178027        Exploits              Browser      sep  175.45.176.3
# 178028        Exploits      Office Document      tcp  175.45.176.0
# 178029        Exploits              Browser      tcp  175.45.176.2
# 178030  Reconnaissance                 ICMP     unas  175.45.176.3
#
#         Source Port  Destination IP  Destination Port  \
# 0             13284  149.171.126.16                80
# ...

# %% [markdown]
# ### a. List different types of attacks

# %%
#to find the unique types of attacks, we can use the unique() function

uniqueattacks = df['Attack category'].unique()

print("The types of attacks are: ",uniqueattacks)
# Out:
# The types of attacks are:  ['Reconnaissance' 'Exploits' 'DoS' 'Generic' 'Shellcode' 'Fuzzers' 'Worms'
#  'Backdoors' 'Analysis' 'Backdoor']

# %% [markdown]
# ### b. Fetch the Protocols, Source and Destination Port and the Category of Attacks having their Source IP as 175.46.176.2.

# %%
print(df['Source IP'].dtype)
# Out:
# object

# %%
attacks =0
df['Source IP'] = df['Source IP'].astype(str)            #converting to string for comparision
attacks = df[df['Source IP']=='175.45.176.2']
attacks = attacks.drop(columns=['Attack subcategory','Destination IP','Attack Name','Attack Reference'])
attacks
# Out:
#        Attack category Protocol     Source IP  Source Port  Destination Port
# 2             Exploits      tcp  175.45.176.2        23357                80
# 3             Exploits      tcp  175.45.176.2        13792              5555
# 4             Exploits      tcp  175.45.176.2        26939                80
# 11            Exploits      tcp  175.45.176.2        43850                80
# 18            Exploits      tcp  175.45.176.2        63163              8080
# ...                ...      ...           ...          ...               ...
# 178000        Exploits     unas  175.45.176.2        76423                 0
# 178003  Reconnaissance      prm  175.45.176.2        73077                 0
# 178016             DoS      tcp  175.45.176.2        76372               389
# 178022        Exploits      tcp  175.45.176.2        59137              -146
# 178029        Exploits      tcp  175.45.176.2        68488                80
#
# [33927 rows x 5 columns]

# %% [markdown]
# ### c.Fetch the name of the attack and subcategory having UDP protocol which comes under DoS category

# %%
udp = df[ (df['Protocol']=='udp') & (df['Attack category']=='DoS')]

udp
# Out:
#        Attack category Attack subcategory Protocol     Source IP  Source Port  \
# 52                 DoS               SNMP      udp  175.45.176.2         6551
# 436                DoS      Miscellaneous      udp  175.45.176.1         2442
# 994                DoS                SIP      udp  175.45.176.1        44675
# 1220               DoS      Miscellaneous      udp  175.45.176.3            0
# 1221               DoS                TCP      udp  175.45.176.3            0
# ...                ...                ...      ...           ...          ...
# 176529             DoS                SSL      udp  175.45.176.1        70955
# 176927             DoS                SSL      udp  175.45.176.0        75076
# 177344             DoS               SMTP      udp  175.45.176.2        73815
# 177776             DoS      Miscellaneous      udp  175.45.176.0        68524
# 177872             DoS        NetBIOS/SMB      udp  175.45.176.2         7413
#
# ...

# %% [markdown]
# ### d. Fetch the Count of each individual attack done in the Destination IP 149.171.126.14

# %%
df['Destination IP'] = df['Destination IP'].astype(str)
df1 = df[ df['Destination IP'] == '149.171.126.14' ]



print("the number of attacks on the destination IP 149.171.126.14 are: ",len(df1['Attack Name']))
# Out:
# the number of attacks on the destination IP 149.171.126.14 are:  12450
